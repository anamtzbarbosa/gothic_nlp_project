# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/gothic_nlp_project /content/

# %%
cd /content/gothic_nlp_project
# Out:
# /content/gothic_nlp_project

# %%
# !python  src/grid_search_v2.py
# Out:
# Streaming output truncated to the last 5000 lines.
#   Batch 5300/20935 | Avg Train Loss: 4.7974
#   Batch 5400/20935 | Avg Train Loss: 4.7865
#   Batch 5500/20935 | Avg Train Loss: 4.7760
#   Batch 5600/20935 | Avg Train Loss: 4.7657
#   Batch 5700/20935 | Avg Train Loss: 4.7556
#   Batch 5800/20935 | Avg Train Loss: 4.7457
#   Batch 5900/20935 | Avg Train Loss: 4.7358
#   Batch 6000/20935 | Avg Train Loss: 4.7262
#   Batch 6100/20935 | Avg Train Loss: 4.7169
#   Batch 6200/20935 | Avg Train Loss: 4.7078
#   Batch 6300/20935 | Avg Train Loss: 4.6988
#   Batch 6400/20935 | Avg Train Loss: 4.6900
#   Batch 6500/20935 | Avg Train Loss: 4.6814
#   Batch 6600/20935 | Avg Train Loss: 4.6730
#   Batch 6700/20935 | Avg Train Loss: 4.6648
#   Batch 6800/20935 | Avg Train Loss: 4.6566
#   Batch 6900/20935 | Avg Train Loss: 4.6485
#   Batch 7000/20935 | Avg Train Loss: 4.6407
#   Batch 7100/20935 | Avg Train Loss: 4.6329
#   Batch 7200/20935 | Avg Train Loss: 4.6253
# ...
